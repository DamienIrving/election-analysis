# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

# %%
state_mps = {}

state_mps['TAS'] = {
    "Cassy O'Connor (LegCo)": np.arange(2024, 2027),
    "Helen Burnet": np.arange(2024, 2026),
    "Tabatha Badger": np.arange(2024, 2027),
    "Cecily Rosol": np.arange(2024, 2027),
    "Vica Bayley": np.arange(2023, 2027),
    "Rosalie Woodruff": np.arange(2015, 2027),
    "Andrea Dawkins": np.arange(2015, 2018),
    "Paul O'Halloran": np.arange(2010, 2014),
    "Cassy O'Connor (HoA)": np.arange(2008, 2023),
    "Nick McKim": np.arange(2002, 2015),
    "Kim Booth": np.arange(2002, 2015),
    "Tim Morris": np.arange(2002, 2014),
    "Mike Foley": np.arange(1995, 1998),
    "Peg Putt": np.arange(1993, 2008),
    "Christine Milne": np.arange(1989, 1998),
    "Di Hollister": np.arange(1989, 1998),
    "Lance Armstrong": np.arange(1989, 1996),
    "Gerry Bates": np.arange(1986, 1995),
    "Bob Brown": np.arange(1983, 1993),
}

state_mps['WA'] = {
    "Sophie McNeill": np.arange(2025, 2027),
    "Tim Clifford (Term 2)": np.arange(2025, 2027),
    "Jess Beckerling": np.arange(2025, 2027),
    "Brad Pettitt": np.arange(2021, 2027),
    "Diane Evers": np.arange(2017, 2021),
    "Tim Clifford (Term 1)": np.arange(2017, 2021),
    "Alison Xamon (Term 2)": np.arange(2017, 2021),
    "Robin Chapple (Term 2)": np.arange(2009, 2021),
    "Lynn MacLaren": np.arange(2009, 2017),
    "Alison Xamon (Term 1)": np.arange(2009, 2013),
    "Adele Carles": np.arange(2009, 2010),
    "Paul Llewellyn": np.arange(2005, 2009),
    "Robin Chapple (Term 1)": np.arange(2001, 2005),
    "Dee Margetts": np.arange(2001, 2005),
    "Giz Watson": np.arange(1997, 2013),
    "Chrissy Sharp": np.arange(1997, 2005),
    "Jim Scott": np.arange(1993, 2005),
}

state_mps['NSW'] = {
    "Amanda Cohn": np.arange(2023, 2027),
    "Kobi Shetty": np.arange(2023, 2027),
    "Sue Higginson": np.arange(2022, 2027),
    "Abigail Boyd": np.arange(2019, 2027),
    "Cate Faehrmann (Term 2)": np.arange(2018, 2027),
    "Dawn Walker": np.arange(2017, 2019),
    "Justin Field": np.arange(2016, 2019),
    "Tamara Smith": np.arange(2015, 2027),
    "Jenny Leong": np.arange(2015, 2027),
    "Mehreen Faruqi": np.arange(2013, 2018),
    "Jamie Parker": np.arange(2011, 2023),
    "Jeremy Buckingham": np.arange(2011, 2018),
    "Jan Barham": np.arange(2011, 2017),
    "David Shoebridge": np.arange(2010, 2022),
    "Cate Faehrmann (Term 1)": np.arange(2010, 2013),
    "John Kaye": np.arange(2007, 2016),
    "Sylvia Hale": np.arange(2003, 2010),
    "Lee Rhiannon": np.arange(1999, 2010),
    "Ian Cohen": np.arange(1995, 2011),
}

state_mps['ACT'] = {
    "Laura Nuttall": np.arange(2023, 2027),
    "Andrew Braddock": np.arange(2020, 2027),
    "Emma Davidson": np.arange(2020, 2024),
    "Rebecca Vassarotti": np.arange(2020, 2024),
    "Jo Clay": np.arange(2020, 2027),
    "Johnathan Davis": np.arange(2020, 2023),
    "Caroline Le Couteur (Term 2)": np.arange(2016, 2020),
    "Shane Rattenbury": np.arange(2008, 2027),
    "Caroline Le Couteur (Term 1)": np.arange(2008, 2012),
    "Amanda Bresnan": np.arange(2008, 2012),
    "Meredith Hunter": np.arange(2008, 2012),
    "Deb Foskey": np.arange(2004, 2008),
    "Kerrie Tucker": np.arange(1995, 2004),
    "Lucy Horodny": np.arange(1995, 1998),
}

state_mps['SA'] = {
    "Melanie Selwood": np.arange(2026, 2027),
    "Robert Simms": np.arange(2021, 2027),
    "Tammy Franks": np.arange(2010, 2025),
    "Mark Parnell": np.arange(2006, 2021),
    "Kris Hanna": np.arange(2003, 2006),
}
# MacLaren was also an MP for 3 months during 2015

state_mps['VIC'] = {
    "Anasina Gray-Barberio": np.arange(2024, 2027),
    "Gabrielle de Vietri": np.arange(2022, 2027),
    "Aiv Puglielli": np.arange(2022, 2027),
    "Sarah Mansfield": np.arange(2022, 2027),
    "Katherine Copsey": np.arange(2022, 2027),
    "Tim Read": np.arange(2018, 2027),
    "Samantha Ratnam": np.arange(2017, 2024),
    "Lidia Thorpe": np.arange(2017, 2018),
    "Ellen Sandell": np.arange(2014, 2027),
    "Sam Hibbins": np.arange(2014, 2024),
    "Nina Springle": np.arange(2014, 2018),
    "Samantha Dunn": np.arange(2014, 2018),
    "Greg Barber": np.arange(2006, 2017),
    "Colleen Hartland": np.arange(2006, 2018),
    "Sue Pennicuik": np.arange(2006, 2018),
}
# Huong Truong replaced Colleen Hartland for much of 2018

state_mps['QLD'] = {
    "Amy MacMahon": np.arange(2020, 2024),
    "Michael Berkman": np.arange(2017, 2027),
    "Ronan Lee": np.arange(2008, 2009),
}

state_mps['NT'] = {
    "Kat McNamara": np.arange(2024, 2026),
}

# %%
#mp_count_dict = {'year': np.arange(1972, 2023)}
mp_count_dict = {'year': np.arange(1983, 2027)}
for state, mp_dict in state_mps.items():
    years = np.concatenate(list(mp_dict.values()))
    counts, lower_bin_bounds = np.histogram(years, bins=np.arange(1982.5, 2027.5))
    mp_count_dict[state] = counts

# %%
df = pd.DataFrame(mp_count_dict)
df = df.set_index('year')
order = ['TAS', 'WA', 'NSW', 'ACT', 'SA', 'VIC', 'QLD', 'NT']
df = df[order]
df
# Out:
#       TAS  WA  NSW  ACT  SA  VIC  QLD  NT
# year
# 1983    1   0    0    0   0    0    0   0
# 1984    1   0    0    0   0    0    0   0
# 1985    1   0    0    0   0    0    0   0
# 1986    2   0    0    0   0    0    0   0
# 1987    2   0    0    0   0    0    0   0
# 1988    2   0    0    0   0    0    0   0
# 1989    5   0    0    0   0    0    0   0
# 1990    5   0    0    0   0    0    0   0
# 1991    5   0    0    0   0    0    0   0
# 1992    5   0    0    0   0    0    0   0
# 1993    5   1    0    0   0    0    0   0
# 1994    5   1    0    0   0    0    0   0
# 1995    5   1    1    2   0    0    0   0
# 1996    4   1    1    2   0    0    0   0
# 1997    4   3    1    2   0    0    0   0
# 1998    1   3    1    1   0    0    0   0
# 1999    1   3    2    1   0    0    0   0
# 2000    1   3    2    1   0    0    0   0
# 2001    1   5    2    1   0    0    0   0
# 2002    4   5    2    1   0    0    0   0
# 2003    4   5    3    1   1    0    0   0
# 2004    4   5    3    1   1    0    0   0
# 2005    4   2    3    1   1    0    0   0
# 2006    4   2    3    1   1    3    0   0
# 2007    4   2    4    1   1    3    0   0
# 2008    4   2    4    4   1    3    1   0
# 2009    4   5    4    4   1    3    0   0
# 2010    5   4    4    4   2    3    0   0
# 2011    5   4    6    4   2    3    0   0
# 2012    5   4    6    1   2    3    0   0
# 2013    5   2    6    1   2    3    0   0
# 2014    3   2    6    1   2    7    0   0
# 2015    3   2    8    1   2    7    0   0
# 2016    3   2    8    2   2    7    0   0
# 2017    3   4    8    2   2    8    1   0
# 2018    2   4    7    2   2    4    1   0
# 2019    2   4    6    2   2    4    1   0
# 2020    2   4    6    6   2    4    2   0
# 2021    2   1    6    6   2    4    2   0
# 2022    2   1    6    6   2    8    2   0
# 2023    2   1    7    6   2    8    2   0
# 2024    6   1    7    4   2    7    1   1
# 2025    6   4    7    4   1    7    1   1
# 2026    5   4    7    4   2    7    1   0

# %%
df.plot(kind='bar', stacked=True, figsize=(12,5), width=1)
plt.title("Greens State/Territory MPs")
plt.ylabel("Number of MPs at year end")
#plt.axhline(y=33, color='grey', linestyle=':')
plt.savefig('state_mps.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# The high water mark was 33 state/territory MPs at the end of August 2024 (between then and the end of 2024 the Greens lost 1 seat at the QLD state election, 2 seats at the ACT election and Sam Hibbins stepped down in Victoria).
