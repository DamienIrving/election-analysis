# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../processed_data/Senate25-Tasmania-polling-place-votes.csv')

# %%
divisions = df['LegCo'].dropna().unique()
divisions = np.sort(divisions)

# %%
for div in divisions:
    greens_votes = df[df['LegCo'] == div]['GreensVotes'].sum()
    total_votes = df[df['LegCo'] == div]['TotalVotes'].sum()
    greens_pct = (greens_votes / total_votes) * 100
    print(div, f'{greens_pct:.2f}%')
# Out:
# Derwent 10.33%
# Elwick 24.87%
# Hobart 42.34%
# Huon 25.23%
# Launceston 16.65%
# McIntyre 10.72%
# Mersey 8.64%
# Montgomery 9.51%
# Murchison 9.89%
# Nelson 29.03%
# Pembroke 21.84%
# Prosser 14.52%
# Rosevears 15.61%
# Rumney 17.73%
# Windermere 11.68%

# %%
councils = df['LocalCouncil'].dropna().unique()
councils = np.sort(councils)
councils
# Out:
# array(["Break O'Day", 'Brighton', 'Burnie City', 'Central Coast',
#        'Central Highlands', 'Circular Head', 'Clarence City',
#        'Derwent Valley', 'Devonport City', 'Dorset', 'Flinders',
#        'George Town', 'Glamorgan-Spring Bay', 'Glenorchy City',
#        'Hobart City', 'Huon Valley', 'Kentish', 'King Island',
#        'Kingborough', 'Latrobe', 'Launceston City', 'Meander Valley',
#        'Northern Midlands', 'Sorell', 'Southern Midlands', 'Tasman',
#        'Waratah-Wynyard', 'West Coast', 'West Tamar'], dtype=object)

# %%
for council in councils:
    greens_votes = df[df['LocalCouncil'] == council]['GreensVotes'].sum()
    total_votes = df[df['LocalCouncil'] == council]['TotalVotes'].sum()
    greens_pct = (greens_votes / total_votes) * 100
    print(council, f'{greens_pct:.2f}%')
# Out:
# Break O'Day 16.79%
# Brighton 8.82%
# Burnie City 9.93%
# Central Coast 9.83%
# Central Highlands 6.41%
# Circular Head 7.96%
# Clarence City 20.56%
# Derwent Valley 10.53%
# Devonport City 8.96%
# Dorset 7.67%
# Flinders 18.08%
# George Town 8.77%
# Glamorgan-Spring Bay 13.38%
# Glenorchy City 19.22%
# Hobart City 38.21%
# Huon Valley 23.05%
# Kentish 9.74%
# King Island 6.56%
# Kingborough 26.58%
# Latrobe 8.06%
# Launceston City 15.39%
# Meander Valley 11.94%
# Northern Midlands 8.29%
# Sorell 20.02%
# Southern Midlands 7.14%
# Tasman 22.28%
# Waratah-Wynyard 10.64%
# West Coast 6.38%
# West Tamar 15.30%
