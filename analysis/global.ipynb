# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# Analysis of MPs from [Global Greens member parties](https://globalgreens.org/member-parties/#).
#
# Possible start dates for the analysis:
# - The first Planetary Meeting of the Greens was held in Rio de Janeiro on May 30–31, 1992
# - The Global Greens officially formed in 2001 at the First Global Greens Congress

# %%
greens_mps = {} # number of MPs after each election
total_mps = {} # size of the national parliament

# %% [markdown]
# ### Albania: Partia E Gjelbër / Green Party of Albania
#
# No MPs in national parliament yet.
# https://en.wikipedia.org/wiki/Green_Party_of_Albania

# %% [markdown]
# ### Algeria: Parti des Verts du Algérie / Algerian Green Party
#
# No MPs yet?

# %% [markdown]
# ### Argentina: Partido Verde Argentina
#
# No MPs yet?
# https://partidoverde.com.ar/

# %% [markdown]
# ### Australia: Australian Greens
#
# https://en.wikipedia.org/wiki/Australian_Greens

# %%
greens_mps['Australia'] = {
    1990: 0,
    1993: 0,
    1996: 0,
    1998: 1,
    2001: 2,
    2004: 4,
    2007: 5,
    2010: 10,
    2013: 11,
    2016: 10,
    2019: 10,
}

total_mps['Australia'] = {
    1990: 147 + 76,
    1996: 148 + 76,
    2001: 150 + 76,
    2019: 151 + 76,
}

# %% [markdown]
# ### Austria: Die Grünen / Austrian Greens
#
# https://en.wikipedia.org/wiki/The_Greens_%E2%80%93_The_Green_Alternative

# %%
greens_mps['Austria'] = {
    1983: 0,
    1986: 8,
    1990: 10,
    1994: 13,
    1995: 9,
    1999: 14,
    2002: 17,
    2006: 21,
    2008: 20,
    2013: 24,
    2017: 0,
    2019: 26,
}

total_mps['Austria'] = {
    1983: 183,
}

# %% [markdown]
# ### Bangladesh: Bangladesh Green Party
#
# No MPs yet.

# %% [markdown]
# ### Belgium: Groen and Ecolo
#
# https://en.wikipedia.org/wiki/Groen_(political_party)
# https://en.wikipedia.org/wiki/Ecolo

# %%
greens_mps['Belgium'] = {
    1977: 0,
    1978: 0,
    1981: 3 + 5,
    1985: 6 + 7,
    1987: 9 + 5,
    1991: 12 + 16,
    1995: 6 + 8,
    1999: 12 + 14,
    2003: 0 + 5,
    2007: 5 + 10,
    2010: 6 + 10,
    2014: 6 + 6,
    2019: 8 + 13,
}

total_mps['Belgium'] = {
    1977: 212 + 106,
    1987: 212 + 105,
    1991: 212 + 70,
    1995: 150 + 40,
    2014: 150,
}

# %% [markdown]
# ### Bolivia: Partido Verde de Bolivia
#
# No MPs yet.

# %% [markdown]
# ### Brazil: Partido Verde (Brazil)
#
# https://en.wikipedia.org/wiki/Green_Party_(Brazil)

# %%
greens_mps['Brazil'] = {
    1998: 1,
    2002: 5,
    2006: 13,
    2010: 15,
    2014: 9,
    2018: 4,
}

total_mps['Brazil'] = {
    1998: 513 + 81,
}

# %% [markdown]
# ### Bulgaria: Zelena Dvizheniye / Green Movement (Bulgaria)
#
# https://en.wikipedia.org/wiki/Green_Party_of_Bulgaria
# https://en.wikipedia.org/wiki/Green_Movement_(Bulgaria)

# %%
#    1989: 17,
#    1991: 0,
#    1994: 0,
#    1997: 2,
#    2005, 0,
#    2007: 0,

greens_mps['Bulgaria'] = {
    2009: 0,
    2013: 0,
    2014: 0,
    2017: 0,
    2021: 2,
}

total_mps['Bulgaria'] = {
    2009: 240,
}

# %% [markdown]
# ### Burkina Faso: Rassemblement des Ecologistes du Burkina Faso
#
# No MPs yet?

# %% [markdown]
# ### Burundi: Burundi Green Movement
#
# No MPs yet?

# %% [markdown]
# ### Canada: Green Party of Canada
#
# https://en.wikipedia.org/wiki/Green_Party_of_Canada

# %%
greens_mps['Canada'] = {
    1984: 0,
    1988: 0,
    1993: 0,
    1997: 0,
    2000: 0,
    2004: 0,
    2006: 0,
    2008: 0,
    2011: 1,
    2015: 1,
    2019: 3,
    2021: 2,
}

total_mps['Canada'] = {
    1984: 282,
    1988: 295,
    1997: 301,
    2004: 308,
    2015: 338,
}

# %% [markdown]
# ### Chad: Union des Ecologistes Tchadiens - LES VERTS
#
# No MPs yet.

# %% [markdown]
# ### Chile: Partido Ecologista Verde de Chile
#
# https://es.wikipedia.org/wiki/Partido_Ecologista_Verde_de_Chile

# %%
greens_mps['Chile'] = {
    2009: 0,
    2013: 0,
    2017: 1,
    2021: 2,
}

total_mps['Chile'] = {
    2009: 120 + 38,
    2017: 155 + 43,
    2021: 155 + 50,
}

# %% [markdown]
# ### Congo: Mouvement des Ecologistes Congolais-Les Verts
#
# No MPs yet.

# %% [markdown]
# ### Congo, the Democratic Republic of the: Alliance des Ecologistes Congolais-Les Verts (AECO-Les Verts)
#
# No MPs yet

# %% [markdown]
# ### Cote d'Ivoire: Rassemblement des Verts Ivoiriens (RAVI)
#
# No MPs yet

# %% [markdown]
# ### Croatia: Orah
#
# https://en.wikipedia.org/wiki/Sustainable_Development_of_Croatia
#
# No MPs yet.

# %% [markdown]
# ### Cyprus: Cyprus Green Party / Movement of Ecologists – Citizens' Cooperation (KOSP)
#
# https://en.wikipedia.org/wiki/Movement_of_Ecologists_%E2%80%93_Citizens%27_Cooperation

# %%
greens_mps['Cyprus'] = {
    2001: 1,
    2006: 1,
    2011: 1,
    2016: 2,
    2021: 3,
}

total_mps['Cyprus'] = {
    2001: 56,
}

# %% [markdown]
# ### Czech Republic: Zelení / Czech Greens
#
# https://en.wikipedia.org/wiki/Green_Party_(Czech_Republic)
#
# Note that senate elections and Chamber of Deputies elections are not held at the same time. (I find the senate results a little confusing - not sure 100% correct).

# %%
greens_mps['Czech Republic'] = {
    1990: 0,
    1992: 3,
    1996: 0,
    1998: 0,
    2002: 0,
    2004: 0 + 1,
    2006: 6 + 1,
    2008: 6 + 1,
    2010: 0,
    2012: 0 + 1,
    2013: 0 + 1,
    2014: 0 + 4,
    2016: 0 + 4,
    2017: 0 + 4,
    2018: 0 + 1,
    2020: 0 + 1,
    2021: 0 + 1,
}

total_mps['Czech Republic'] = {
    1990: 200,
    1996: 200 + 81,
}

# %% [markdown]
# ### Denmark: Socialistisk Folkeparti
#
# https://en.wikipedia.org/wiki/Socialist_People%27s_Party_(Denmark)
#
# FIXME: This socialist party has been around since the 1960s. It joined the European Greens (and thus the Global Greens) in 2014, but sat with similar international Green groups dating back to 1994.

# %%
# MPs since they joined the Global Greens in 2014 (so the 2014 number is from 2011 election)

greens_mps['Denmark'] = {
    2014: 16,  
    2015:  7, 
    2019: 14,
    
}

total_mps['Denmark'] = {
    2014: 179
}

# %% [markdown]
# ### Dominican Republic: Partido Verde Dominicano
#
# No MPs yet.

# %% [markdown]
# ### Egypt: Egyptian Green Party
#
# No MPs yet.

# %% [markdown]
# ### Estonia: Eestimaa Rohelised / Estonian Greens
#
# https://en.wikipedia.org/wiki/Estonian_Greens
#
# Rein Järlik was also elected in 1992 running for an earlier iteration of the Estonian Greens. He was an MP until 1999 but at some point during the period 1992-1999 he left the Greens for a different party (not sure if it was when the party folded in 1998).

# %%
greens_mps['Estonia'] = {
    2007: 6,
    2011: 0,
    2015: 0,
    2019: 0,
}

total_mps['Estonia'] = {
    2007: 101,
}

# %% [markdown]
# ### Finland: Vihreät de Gröna
#
# https://en.wikipedia.org/wiki/Green_League

# %%
greens_mps['Finland'] = {
    1983: 2,
    1987: 4,
    1991: 10,
    1995: 9,
    1999: 11,
    2003: 14,
    2007: 15,
    2011: 10,
    2015: 15,
    2019: 20,
}

total_mps['Finland'] = {
    1983: 200,
}

# %% [markdown]
# ### France: Europe Ecologie - Les Verts
#
# https://en.wikipedia.org/wiki/Europe_Ecology_%E2%80%93_The_Greens
# https://en.wikipedia.org/wiki/The_Greens_(France)

# %%
greens_mps['France'] = {
    1986: 0,
    1988: 0,
    1993: 0,
    1997: 7,
    2002: 3,
    2007: 4,
    2012: 17,
    2017: 1,
}

total_mps['France'] = {
    1986: 577,
}

# %% [markdown]
# ### Georgia: Sakartvelo's mtsvaneta partia / Georgian Greens Party

# %%
greens_mps['Georgia'] = {
    1990: 0,
    1992: 11,
    1995: 2,
    1999: 0,
    2008: 0,
    2012: 6,
    2016: 6,
    2020: 0,
}

total_mps['Georgia'] = {
    1990: 225,
    2008: 150,
}

# %% [markdown]
# ### Germany: Bündnis 90 Die Grünen (German Greens)
#
# https://en.wikipedia.org/wiki/Alliance_90/The_Greens

# %%
greens_mps['Germany'] = {
    1980: 0,
    1983: 27,
    1987: 42,
    1990: 8,
    1994: 49,
    1998: 47,
    2002: 55,
    2005: 51,
    2009: 68,
    2013: 63,
    2017: 67,
    2021: 118,
}

total_mps['Germany'] = {
    1980: 497,
    1983: 498,
    1987: 497,
    1990: 662,
    1994: 672,
    1998: 669,
    2002: 603,
    2005: 614,
    2009: 622,
    2013: 630,
    2017: 709,
    2021: 735,
}

# %% [markdown]
# ### Greece: Ecologist Greens
#
# https://en.wikipedia.org/wiki/Ecologist_Greens

# %%
greens_mps['Greece'] = {
    2015: 2,
    2019: 0,
}

total_mps['Greece'] = {
    2015: 300
}

# %% [markdown]
# ### Guatemala: Movimiento Verde
#
# No MPs yet.

# %% [markdown]
# ### Hungary: Magyarország Zöld Pártja / Hungary's Green Party
#
# https://en.wikipedia.org/wiki/LMP_%E2%80%93_Hungary%27s_Green_Party

# %%
greens_mps['Hungary'] = {
    2010: 16,
    2014: 5,
    2018: 8,
}

total_mps['Hungary'] = {
    2010: 386,
    2014: 199,
}

# %% [markdown]
# ### India: Uttarakhand Parivartan Party (UKPP) / India Greens Party
#
# No MPs yet.

# %% [markdown]
# ### Indonesia: Atjeh Green Party
#
# No MPs yet.

# %% [markdown]
# ### Iraq: Green Party of Iraq
#
# No MPs yet.

# %% [markdown]
# ### Ireland: Comhaontas Glas (Green Party Ireland)
#
# https://en.wikipedia.org/wiki/Green_Party_(Ireland)

# %%
greens_mps['Ireland'] = {
    1982: 0,
    1987: 0,
    1989: 1,
    1992: 1,
    1997: 2,
    2002: 6,
    2007: 6,
    2011: 0,
    2016: 2,
    2020: 12,
}

total_mps['Ireland'] = {
    1982: 166,
    2016: 158,
    2020: 160,
}

# %% [markdown]
# ### Italy: Federazione dei Verdi & Verdi-Grüne-Vërc
#
# https://en.wikipedia.org/wiki/Federation_of_the_Greens
# https://en.wikipedia.org/wiki/Greens_(South_Tyrol)
#
# These parties are now part of [Green Europe](https://en.wikipedia.org/wiki/Green_Europe).
# This might mean that I can include the 2 MPs that [Green Italia](https://en.wikipedia.org/wiki/Green_Italia) have?

# %%
greens_mps['Italy'] = {
    1987: 13 + 1,
    1992: 16 + 4,
    1994: 11 + 7,
    1996: 14 + 14,
    2001: 8 + 8,
    2006: 15 + 11,
    2008: 0 + 0,
    2013: 0 + 0,
    2018: 0 + 0,
}

total_mps['Italy'] = {
    1987: 630 + 315,
}

# %% [markdown]
# ### Japan: Greens Japan
#
# No MPs yet.

# %% [markdown]
# ### Korea, Republic of: Green Party Korea
#
# No MPs yet.

# %% [markdown]
# ### Lebanon: Lebanon Green Party
#
# No MPs yet.

# %% [markdown]
# ### Luxembourg: Déi Gréng
#
# https://en.wikipedia.org/wiki/The_Greens_(Luxembourg)

# %%
greens_mps['Luxembourg'] = {
    1984: 2,
    1989: 4,
    1994: 5,
    1999: 5,
    2004: 7,
    2009: 7,
    2013: 6,
    2018: 9,
}

total_mps['Luxembourg'] = {
    1984: 64,
    1989: 60,
}

# %% [markdown]
# ### Macedonia, the former Yugoslav Republic of: Demokratska Obnova na Makedonija (North Macedonia)
#
# https://en.wikipedia.org/wiki/Democratic_Renewal_of_Macedonia

# %%
greens_mps['Macedonia'] = {
    2006: 1,
    2008: 1,
    2011: 1,
    2016: 1,
    2020: 1,
}

total_mps['Macedonia'] = {
    2006: 120,
}

# %% [markdown]
# ### Madagascar: Parti Vert Hasin’I Madagasikara
#
# https://en.wikipedia.org/wiki/Madagascar_Green_Party

# %%
greens_mps['Madagascar'] = {
    2013: 2,
    2019: 0,
}

total_mps['Madagascar'] = {
    2013: 151,
}

# %% [markdown]
# ### New Zealand: Green Party of Aotearoa New Zealand
#
# https://en.wikipedia.org/wiki/Green_Party_of_Aotearoa_New_Zealand

# %%
greens_mps['New Zealand'] = {
    1990: 0,
    1993: 0,
    1996: 3,
    1999: 7,
    2002: 9,
    2005: 6,
    2008: 9,
    2011: 14,
    2014: 14,
    2017: 8,
    2020: 10,
}

total_mps['New Zealand'] = {
    1990: 97,
    1993: 99,
    1996: 120,
    2005: 121,
    2008: 122,
    2011: 121,
    2017: 120,
}

# %% [markdown]
# ### Rwanda: Democratic Green party of Rwanda
#
# https://en.wikipedia.org/wiki/Democratic_Green_Party_of_Rwanda

# %%
greens_mps['Rwanda'] = {
    2018: 2,
}

total_mps['Rwanda'] = {
    2018: 80,
}

# %%
greens_mps.keys()
# Out:
# dict_keys(['Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia', 'Germany', 'New Zealand', 'Rwanda'])

# %%
years = np.arange(1977, 2022)
countries = [
    'Australia',
    'Austria',
    'Belgium',
    'Brazil',
    'Bulgaria',
    'Canada',
    'Chile',
    'Cyprus',
    'Czech Republic',
    'Denmark',
    'Estonia',
    'Finland',
    'France',
    'Georgia',
    'Germany',
    'Greece',
    'New Zealand',
    'Rwanda',
]

# %%
def fill_mps_list(mps_dict, years):
    """Create array of MPs for each year"""

    last_mps = 0
    mps_list = []
    for year in years:
        if year in mps_dict:
            last_mps = mps_dict[year]
        mps_list.append(last_mps)

    return np.array(mps_list)

# %%
greens_mps_arrays = {}
total_mps_arrays = {}
for country in countries:
    greens_mps_arrays[country] = fill_mps_list(greens_mps[country], years)
    total_mps_arrays[country] = fill_mps_list(total_mps[country], years)

# %%
greens_df = pd.DataFrame(greens_mps_arrays)
greens_df = greens_df.set_index(years)
greens_df = greens_df[countries]
greens_df
# Out:
#       Australia  Austria  Belgium  Brazil  Bulgaria  Canada  Chile  Cyprus  \
# 1977          0        0        0       0         0       0      0       0
# 1978          0        0        0       0         0       0      0       0
# 1979          0        0        0       0         0       0      0       0
# 1980          0        0        0       0         0       0      0       0
# 1981          0        0        8       0         0       0      0       0
# 1982          0        0        8       0         0       0      0       0
# 1983          0        0        8       0         0       0      0       0
# 1984          0        0        8       0         0       0      0       0
# 1985          0        0       13       0         0       0      0       0
# 1986          0        8       13       0         0       0      0       0
# 1987          0        8       14       0         0       0      0       0
# 1988          0        8       14       0         0       0      0       0
# 1989          0        8       14       0         0       0      0       0
# 1990          0       10       14       0         0       0      0       0
# 1991          0       10       28       0         0       0      0       0
# 1992          0       10       28       0         0       0      0       0
# 1993          0       10       28       0         0       0      0       0
# 1994          0       13       28       0         0       0      0       0
# 1995          0        9       14       0         0       0      0       0
# 1996          0        9       14       0         0       0      0       0
# 1997          0        9       14       0         0       0      0       0
# 1998          1        9       14       1         0       0      0       0
# 1999          1       14       26       1         0       0      0       0
# 2000          1       14       26       1         0       0      0       0
# 2001          2       14       26       1         0       0      0       1
# 2002          2       17       26       5         0       0      0       1
# 2003          2       17        5       5         0       0      0       1
# 2004          4       17        5       5         0       0      0       1
# 2005          4       17        5       5         0       0      0       1
# 2006          4       21        5      13         0       0      0       1
# 2007          5       21       15      13         0       0      0       1
# 2008          5       20       15      13         0       0      0       1
# 2009          5       20       15      13         0       0      0       1
# 2010         10       20       16      15         0       0      0       1
# 2011         10       20       16      15         0       1      0       1
# 2012         10       20       16      15         0       1      0       1
# 2013         11       24       16      15         0       1      0       1
# 2014         11       24       12       9         0       1      0       1
# 2015         11       24       12       9         0       1      0       1
# 2016         10       24       12       9         0       1      0       2
# 2017         10        0       12       9         0       1      1       2
# 2018         10        0       12       4         0       1      1       2
# 2019         10       26       21       4         0       3      1       2
# 2020         10       26       21       4         0       3      1       2
# 2021         10       26       21       4         2       2      2       3
#
#       Czech Republic  Denmark  Estonia  Finland  France  Georgia  Germany  \
# 1977               0        0        0        0       0        0        0
# 1978               0        0        0        0       0        0        0
# 1979               0        0        0        0       0        0        0
# 1980               0        0        0        0       0        0        0
# 1981               0        0        0        0       0        0        0
# 1982               0        0        0        0       0        0        0
# 1983               0        0        0        2       0        0       27
# 1984               0        0        0        2       0        0       27
# 1985               0        0        0        2       0        0       27
# 1986               0        0        0        2       0        0       27
# 1987               0        0        0        4       0        0       42
# 1988               0        0        0        4       0        0       42
# 1989               0        0        0        4       0        0       42
# 1990               0        0        0        4       0        0        8
# 1991               0        0        0       10       0        0        8
# 1992               3        0        0       10       0       11        8
# 1993               3        0        0       10       0       11        8
# 1994               3        0        0       10       0       11       49
# 1995               3        0        0        9       0        2       49
# 1996               0        0        0        9       0        2       49
# 1997               0        0        0        9       7        2       49
# 1998               0        0        0        9       7        2       47
# 1999               0        0        0       11       7        0       47
# 2000               0        0        0       11       7        0       47
# 2001               0        0        0       11       7        0       47
# 2002               0        0        0       11       3        0       55
# 2003               0        0        0       14       3        0       55
# 2004               1        0        0       14       3        0       55
# 2005               1        0        0       14       3        0       51
# 2006               7        0        0       14       3        0       51
# 2007               7        0        6       15       4        0       51
# 2008               7        0        6       15       4        0       51
# 2009               7        0        6       15       4        0       68
# 2010               0        0        6       15       4        0       68
# 2011               0        0        0       10       4        0       68
# 2012               1        0        0       10      17        6       68
# 2013               1        0        0       10      17        6       63
# 2014               4       16        0       10      17        6       63
# 2015               4        7        0       15      17        6       63
# 2016               4        7        0       15      17        6       63
# 2017               4        7        0       15       1        6       67
# 2018               1        7        0       15       1        6       67
# 2019               1       14        0       20       1        6       67
# 2020               1       14        0       20       1        0       67
# 2021               1       14        0       20       1        0      118
#
#       New Zealand  Rwanda
# 1977            0       0
# 1978            0       0
# 1979            0       0
# 1980            0       0
# 1981            0       0
# 1982            0       0
# 1983            0       0
# 1984            0       0
# 1985            0       0
# 1986            0       0
# 1987            0       0
# 1988            0       0
# 1989            0       0
# 1990            0       0
# 1991            0       0
# 1992            0       0
# 1993            0       0
# 1994            0       0
# 1995            0       0
# 1996            3       0
# 1997            3       0
# 1998            3       0
# 1999            7       0
# 2000            7       0
# 2001            7       0
# 2002            9       0
# 2003            9       0
# 2004            9       0
# 2005            6       0
# 2006            6       0
# 2007            6       0
# 2008            9       0
# 2009            9       0
# 2010            9       0
# 2011           14       0
# 2012           14       0
# 2013           14       0
# 2014           14       0
# 2015           14       0
# 2016           14       0
# 2017            8       0
# 2018            8       2
# 2019            8       2
# 2020           10       2
# 2021           10       2

# %%
greens_df.plot(kind='bar', stacked=True, figsize=(9,5), width=1)
plt.title("Greens in National Parliaments")
plt.ylabel("Number of MPs at year end")
plt.savefig('global_greens_mps.png', dpi=300, bbox_inches='tight')

# %%
total_df = pd.DataFrame(total_mps_arrays)
total_df = total_df.set_index(years)
total_df = total_df[countries]

greens_fraction_df = greens_df / total_df

# %%
greens_fraction_df.plot(kind='bar', stacked=True, figsize=(9,5), width=1)
plt.title("Greens in National Parliaments")
plt.ylabel("Fraction of all MPs at year end")
plt.savefig('global_greens_parliament_fractions.png', dpi=300, bbox_inches='tight')

# %%
# Scraps

# %%
mps['AUS'] = {"Jo Vallentine": np.arange(1990, 1992),
              "Christabel Chamarette": np.arange(1992, 1996),
              "Dee Margetts": np.arange(1993, 1999),
              "Rachel Siewert": np.arange(2005, 2022),
              "Scott Ludlam": np.arange(2008, 2017),
              "Jordan Steele-John": np.arange(2017, 2022),
              "Bob Brown": np.arange(1996, 2012),
              "Christine Milne": np.arange(2005, 2015),
              "Nick McKim": np.arange(2015, 2022),
              "Peter Whish-Wilson": np.arange(2012, 2022),
              "Michael Organ": np.arange(2002, 2004),
              "Kerry Nettle": np.arange(2002, 2008),
              "Lee Rhiannon": np.arange(2011, 2018),
              "Mehreen Faruqi": np.arange(2018, 2022),
              "Sarah Hanson-Young": np.arange(2008, 2022),
              "Penny Wright": np.arange(2011, 2015),
              "Robert Simms": np.arange(2015, 2016),
              "Richard Di Natale": np.arange(2011, 2020),
              "Janet Rice": np.arange(2014, 2022),
              "Lidia Thorpe": np.arange(2020, 2022),
              "Larissa Waters (term 1)": np.arange(2011, 2017),
              "Larissa Waters (term 2)": np.arange(2018, 2022),
              "Andrew Bartlett": np.arange(2017, 2018),
              "Adam Bandt": np.arange(2010, 2022),
             }

mps['NZ'] = {"Marama Davidson": np.arange(2015, 2022),
             "James Shaw": np.arange(2014, 2022),
             "Chloe Swarbrick": np.arange(2017, 2022),
             "Julie Anne Genter": np.arange(2011, 2022),
             "Jan Logie": np.arange(2011, 2022),
             "Eugenie Sage": np.arange(2011, 2022),
             "Golriz Ghahraman": np.arange(2017, 2022),
             "Teanau Tuiono": np.arange(2020, 2022),
             "Elizabeth Kerekere": np.arange(2020, 2022),
             "Ricardo Menendez-March": np.arange(2020, 2022),
            }

mps['BRA'] = {'Fernando Gabeira (term 1)': np.arange(1995, 2003),
              'Fernando Gabeira (term 2)': np.arange(2005, 2012),
              'Célio Studart': np.arange(2019, 2022),
              'Enrico Misasi': np.arange(2019, 2022),
              'Israel Batista': np.arange(2019, 2022),
              'Leandre Dal Ponte': np.arange(2015, 2022),
              'Evandro Gussi': np.arange(2015, 2019),
              'Evair de Melo': np.arange(2015, 2019),
              'Sarney Filho': np.arange(2005, 2019),
              'Victor Mendes': np.arange(2015, 2019),
              'Fabinho Ramalho': np.arange(2011, 2019),
              'Roberto de Lucena': np.arange(2011, 2019),
              'Sinval Malheiros': np.arange(2007, 2019),
              'Antonio Roberto': np.arange(2011, 2015),
              'Denilson Teixeira': np.arange(2011, 2015),
              'Aluizio dos Santos Junior': np.arange(2011, 2013),
              'Eurico Júnior': np.arange(2013, 2015),
              'Henrique Afonso': np.arange(2011, 2015),
              'Lindomar Garçon': np.arange(2011, 2015),
              'Paulo Wagner': np.arange(2011, 2015),
              'José Luiz Penna': np.arange(2011, 2015),
              'Rosane Ferreira': np.arange(2011, 2015),
              'Rosy de Sousa': np.arange(2011, 2015)
             }
# Need to come back and finish Brazil so numbers match: https://en.wikipedia.org/wiki/Green_Party_(Brazil)
# Aluizio dos Santos Junior resigned in 2012 to become mayor of Macae
