# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
emrs_dates = pd.to_datetime([
    '2024-02-17',
    '2024-05-17',
    '2024-08-17',
    '2024-11-17',
    '2025-02-17',
    '2025-05-17',
    '2025-06-17',
    '2025-07-01',
    '2025-07-08',
    '2025-07-15',
    '2025-08-29',
    '2025-11-24',
    '2026-02-23',
    '2026-05-18',
    '2026-08-21'
])

election_dates = pd.to_datetime([
    '2024-03-23',
    '2025-07-19',
])

# %%
emrs_data = {
    'Liberal': [39, 35, 36, 35, 34, 29, 32, 35, 37, 37, 38, 34, 29, 25, 26],
    'Labor': [26, 28, 27, 31, 30, 31, 29, 28, 26, 26, 24, 25, 23, 24, 23],
    'Greens': [12, 15, 14, 14, 13, 14, 14, 14, 15, 14, 13, 17, 15, 14, 16],
    'Independent': [14, 12, 12, 11, 12, 17, 19, 18, 18, 19, 19, 19, 15, 16, 14],
    'Jacqui Lambie Network': [9, 7, 8, 6, 8, 6, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
    'Nationals': [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 2, 2, 3, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
    'One Nation': [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 14, 19, 21],
    'Other': [1, 3, 3, 3, 3, 4, 4, 4, np.nan, 4, 6, 6, 3, 2, 1],
}

election_data = {
    '_Liberal': [37, 40],
    '_Labor': [29, 26],
    '_Greens': [14, 14],
    '_Independent': [10, 15],
    '_Jacqui Lambie Network': [7, np.nan],
    '_Nationals': [np.nan, 2],
    '_Other': [4, 3],
}

# %%
emrs_df = pd.DataFrame(data=emrs_data, index=emrs_dates)

# %%
election_df = pd.DataFrame(data=election_data, index=election_dates)

# %%
emrs_df.sum(axis=1)
# Out:
# 2024-02-17    101.0
# 2024-05-17    100.0
# 2024-08-17    100.0
# 2024-11-17    100.0
# 2025-02-17    100.0
# 2025-05-17    101.0
# 2025-06-17    100.0
# 2025-07-01    101.0
# 2025-07-08     99.0
# 2025-07-15    100.0
# 2025-08-29    100.0
# 2025-11-24    101.0
# 2026-02-23     99.0
# 2026-05-18    100.0
# 2026-08-21    101.0
# dtype: float64

# %%
election_df.sum(axis=1)
# Out:
# 2024-03-23    101.0
# 2025-07-19    100.0
# dtype: float64

# %%
fig, ax = plt.subplots()

emrs_df.plot(
    ax=ax,
    color=['tab:blue', 'tab:red', 'limegreen', 'tab:gray', '#F1CE63', 'tab:green', 'tab:orange', 'tab:pink'],
    marker='o',
    figsize=[8, 5],
)

election_df.plot(
    ax=ax,
    linestyle='none',
    markerfacecolor='none', 
    color=['tab:blue', 'tab:red', 'limegreen', 'tab:gray', '#F1CE63', 'tab:green', 'tab:pink'],
    marker='o',
    figsize=[8, 5],
    legend=False,
)

ax.grid()
#ax.axhline(y=37, color='tab:blue', linestyle=':')
#ax.axhline(y=29, color='tab:red', linestyle=':')
#ax.axhline(y=14, color='limegreen', linestyle=':')
#ax.axhline(y=10, color='tab:gray', linestyle=':')
#ax.axhline(y=4, color='tab:pink', linestyle=':')
ax.axvline(x=election_dates[0], color='black', linestyle=':', label='election result (not EMRS)')
ax.axvline(x=election_dates[1], color='black', linestyle=':')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set_title('EMRS polling (Tasmania, statewide)')
ax.set_ylabel('primary vote (%)')
plt.savefig('emrs.png', bbox_inches='tight', facecolor='white', dpi=300)
