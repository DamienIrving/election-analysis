# %%
import warnings
warnings.filterwarnings('ignore')

import seaborn as sns

import geoviews as gv
gv.extension('matplotlib')
# %output fig='png' size=100
# %output dpi=700

import elections
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
electorates = ['Bass', 'Braddon', 'Clark', 'Franklin', 'Lyons']
df = elections.create_mega_df(electorates, 2019, 2016, remove_prepoll=True)

# %%
tiles, points = elections.vote_plot_setup(df, 'matplotlib', electorate='Franklin')
tiles * points
# Out:
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/damienirving/anaconda/envs/elections/lib/python3.7/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (PollingPlaceNm,GreensVotes,TotalVotes,GreensPercentage)

# %%
df.sort_values(by=['Swing'], ascending=False).dropna()
# Out:
#                            PollingPlaceNm  \
# PollingPlaceID
# 8456                            Fern Tree
# 8445                             Cascades
# 8461                  Hobart City (Clark)
# 8536                     Seven Mile Beach
# 8481                          West Hobart
# 8498                        Blackmans Bay
# 8314                            Five Ways
# 8458                    Glenorchy Central
# 8523                  Lindisfarne Village
# 8469                               Lutana
# 8521            Kingston Beach (Franklin)
# 8295                                Derby
# 8442                        Battery Point
# 8316                              Lebrina
# 8467                         Lenah Valley
# 8453                             Dynnyrne
# 8520                  Kingston (Franklin)
# 8486                       Waimea Heights
# 46852                    Kingston (Clark)
# 8556                              Bicheno
# 8514                       Mountain River
# 8482                            Sandy Bay
# 8472                         Moonah North
# 8597                              Forcett
# 8516                               Howrah
# 8476                             New Town
# 8473                         Mount Nelson
# 8484                 North Hobart Central
# 8465                    West Hobart South
# 8546                           Woodbridge
# ...                                   ...
# 8596                               Fingal
# 8631                           Mole Creek
# 8515                               Howden
# 8319                             Lilydale
# 8416                          South Riana
# 8378                              Elliott
# 8390                       Shorewell Park
# 8678                            Triabunna
# 8406                              Preston
# 8583                            Dromedary
# 8361                            Heybridge
# 8308                              Karoola
# 8412                        Sisters Beach
# 8411                           Rocky Cape
# 8654                              Railton
# 8587                       Elizabeth Town
# 8627                              Meander
# 8620                     Lower Barrington
# 8290                            Branxholm
# 8573                            Coles Bay
# 8433                         Wynyard West
# 8332                         Pipers River
# 8362                         Boat Harbour
# 8570                            Chudleigh
# 8393                              Melrose
# 8693                               Wilmot
# 8402                         North Motton
# 8367                               Calder
# 8575                              Copping
# 8539                            Southport
#
#                                                       PremisesNm   Latitude  \
# PollingPlaceID
# 8456                                  Fern Tree Community Centre -42.922300
# 8445                                 South Hobart Primary School -42.892494
# 8461                                            144 Macquarie St -42.885223
# 8536                   Ramada Resort By Wyndham Seven Mile Beach -42.852600
# 8481                                           St Mary's College -42.881216
# 8498                                Blackmans Bay Primary School -42.996938
# 8314                                     Kim Roe School of Dance -41.457583
# 8458                                              YMCA of Hobart -42.832197
# 8523                      Lindisfarne Citizens Activities Centre -42.847111
# 8469                                     Southern ITF Taekwon-Do -42.843166
# 8521                                         Kingston Beach Hall -42.981534
# 8295                                             Derby Town Hall -41.149330
# 8442                               Albuera Street Primary School -42.891200
# 8316                                       Lebrina Memorial Hall -41.177300
# 8467                                 Lenah Valley Primary School -42.861200
# 8453                               Princes Street Primary School -42.898400
# 8520                                   Kingborough Community Hub -42.976944
# 8486                               Waimea Heights Primary School -42.909011
# 46852                                  Kingborough Community Hub -42.976944
# 8556                                   Bicheno War Memorial Hall -41.874300
# 8514                                Mountain River Memorial Hall -42.961400
# 8482                             Wellspring Anglican Church Hall -42.899200
# 8472                                       Moonah Primary School -42.838000
# 8597                                         Forcett Public Hall -42.806209
# 8516                                           Howrah Scout Hall -42.881900
# 8476                                          The Friends School -42.867000
# 8473                                    Mt Nelson Primary School -42.913600
# 8484                                 Hobart North Uniting Church -42.872800
# 8465                              Goulburn Street Primary School -42.887800
# 8546                                             Woodbridge Hall -43.160100
# ...                                                          ...        ...
# 8596            Fingal Activity Centre (former Council Chambers) -41.638074
# 8631                                   Mole Creek Primary School -41.557472
# 8515                                         Howden Fire Station -43.019128
# 8319                                      Lilydale Memorial Hall -41.252300
# 8416                                            South Riana Hall -41.234500
# 8378                                    Elliott Community Centre -41.092200
# 8390                                             Hellyer College -41.061280
# 8678                                              Triabunna Hall -42.508220
# 8406                                    Preston Community Centre -41.297200
# 8583                         Dromedary (Millvale) Community Hall -42.728200
# 8361                                           Blythe Heads Hall -41.075100
# 8308                                                Karoola Hall -41.253900
# 8412                                  Sisters Beach Fire Station -40.918100
# 8411                                      Rocky Cape Public Hall -40.905000
# 8575            147.802747      Lyons         219           39
# 8539            146.959638   Franklin         166           22
#
#                 GreensPercentage  GreensPercentagePrevious      Swing
# PollingPlaceID
# 8456                   51.340996                 41.101695  10.239301
# 8445                   51.266376                 42.207792   9.058583
# 8461                   37.904968                 29.765258   8.139709
# 8536                   20.184544                 12.244898   7.939646
# 8481                   34.920635                 27.316486   7.604149
# 8498                   22.993492                 15.558384   7.435109
# 8314                   16.830467                  9.610802   7.219665
# 8458                   14.673913                  7.533806   7.140108
# 8523                   18.097754                 11.871345   6.226409
# 8469                   18.122271                 12.040816   6.081454
# 8521                   23.371429                 17.411765   5.959664
# 8295                   17.910448                 12.396694   5.513754
# 8442                   33.048433                 27.601810   5.446623
# 8316                   14.864865                  9.426230   5.438635
# 8467                   24.597606                 19.173630   5.423976
# 8453                   32.615894                 27.399381   5.216513
# 8520                   18.809318                 13.618677   5.190641
# 8486                   20.170758                 15.011820   5.158937
# 46852                  26.340694                 21.199442   5.141252
# 8556                   17.089679                 11.954766   5.134913
# 8514                   20.241692                 15.136876   5.104816
# 8482                   24.028269                 19.011142   5.017126
# 8472                   17.803769                 12.795905   5.007863
# 8597                   11.547912                  6.779661   4.768251
# 8516                   13.410818                  8.664547   4.746271
# 8476                   30.017921                 25.303788   4.714133
# 8473                   29.599407                 24.924471   4.674935
# 8484                   34.054431                 29.433140   4.621292
# 8465                   40.835031                 36.311787   4.523243
# 8546                   32.411067                 27.954545   4.456522
# ...                          ...                       ...        ...
# 8596                    2.826855                  4.285714  -1.458859
# 8631                    9.230769                 10.746269  -1.515499
# 8515                   23.678161                 25.217391  -1.539230
# 8319                   13.421829                 14.979757  -1.557928
# 8416                    6.179775                  7.772021  -1.592245
# 8378                    6.722689                  8.358209  -1.635520
# 8390                    3.649635                  5.303761  -1.654126
# 8678                    3.506098                  5.190840  -1.684742
# 8406                    4.724409                  6.766917  -2.042508
# 8583                    7.816712                  9.863014  -2.046302
# 8361                    3.942652                  6.000000  -2.057348
# 8308                    8.682635                 11.011905  -2.329270
# 8412                   11.330049                 13.903743  -2.573694
# 8411                    1.298701                  4.047619  -2.748918
# 8654                    4.310345                  7.073509  -2.763164
# 8587                    6.784661                  9.620253  -2.835592
# 8627                   13.008130                 15.873016  -2.864886
# 8620                    6.161972                  9.045226  -2.883254
# 8290                    6.763285                  9.708738  -2.945453
# 8573                   21.052632                 24.113475  -3.060844
# 8433                    3.453947                  6.662135  -3.208187
# 8332                    3.319502                  7.024793  -3.705291
# 8362                    7.407407                 11.509434  -4.102027
# 8570                   10.408922                 15.384615  -4.975693
# 8393                    6.008584                 11.063830  -5.055246
# 8693                   10.599078                 15.983607  -5.384528
# 8402                    3.146853                  9.337349  -6.190496
# 8367                    2.580645                 10.055866  -7.475221
# 8575                   17.808219                 26.556017  -8.747797
# 8539                   13.253012                 23.214286  -9.961274
#
# [249 rows x 10 columns]

# %%
# %matplotlib inline

# %%
sns.regplot(x="GreensPercentage", y="Swing", data=df.dropna())
